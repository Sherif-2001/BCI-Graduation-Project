# %% [markdown]
# # Importing Packages

# %%
# !pip install braindecode
# !pip install mne
# Out:
# Collecting braindecode
#   Downloading braindecode-0.8.1-py3-none-any.whl (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.2/165.2 kB 3.9 MB/s eta 0:00:00
# Collecting mne (from braindecode)
#   Downloading mne-1.6.1-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from braindecode) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from braindecode) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from braindecode) (1.11.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from braindecode) (3.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from braindecode) (3.9.0)
# Collecting skorch (from braindecode)
#   Downloading skorch-0.15.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from braindecode) (2.1.0+cu121)
# Collecting einops (from braindecode)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from braindecode) (1.3.2)
# Collecting torchinfo (from braindecode)
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Collecting docstring-inheritance (from braindecode)
#   Downloading docstring_inheritance-2.1.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->braindecode) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne->braindecode) (4.66.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne->braindecode) (1.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne->braindecode) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne->braindecode) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne->braindecode) (0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->braindecode) (2023.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from skorch->braindecode) (1.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from skorch->braindecode) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->braindecode) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->braindecode) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->braindecode) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->braindecode) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->braindecode) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->braindecode) (2.1.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne->braindecode) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne->braindecode) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->braindecode) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->skorch->braindecode) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne->braindecode) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->braindecode) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->braindecode) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->braindecode) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->braindecode) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->braindecode) (2024.2.2)
# Installing collected packages: torchinfo, einops, docstring-inheritance, skorch, mne, braindecode
# Successfully installed braindecode-0.8.1 docstring-inheritance-2.1.2 einops-0.7.0 mne-1.6.1 skorch-0.15.0 torchinfo-1.8.0
# Requirement already satisfied: mne in /usr/local/lib/python3.10/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.25.2)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (23.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)

# %%
import braindecode

# %%
import mne
from scipy.io import loadmat
import scipy
import sklearn
import numpy as np
import pandas as pd
import glob
from mne.decoding import CSP
import os

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as lda

# %%
import warnings
warnings.filterwarnings('ignore') # to ignore warnings

# %%
verbose = False                    # global variable to suppress output display of MNE functions
mne.set_log_level(verbose=verbose) # to suppress large info outputs

# %%
n_jobs = None  # for multicore parallel processing, set it to 1 if cause memory issues, for full utilization set to -1

# %% [markdown]
# # Data Loading and Conversion to MNE Datatypes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = "/content/drive/MyDrive/GP/Data"

# %%
training_files   = glob.glob(folder_path + '/*T.mat')
len(training_files)     # if  return zero,then no file is loaded
# Out:
# 10

# %%
# we have modified the labels values from [1, 2] to [0, 1] as pytorch
# expects labels/classes to be in [0, n_classes-1] format
def get_mne_epochs(filepath, verbose=verbose, t_start=2, fs=512, mode='train'):
    '''
    This function reads the EEG data from .mat file and convert it to MNE-Python Compatible epochs
    data structure. It takes data from [0, 8] sec range and return it by setting t = 0 at cue onset
    i.e. 3 seconds and dropping first two seconds so the output data is in [-1.0, 5.0] sec range. The
    Details can be found in the preprocessing section of the attached document
    '''
    mat_data = loadmat(filepath) # read .mat file
    eeg_data= mat_data['RawEEGData']
    idx_start = fs*t_start
    eeg_data = eeg_data[:, :, idx_start:]
    event_id = {'left-hand': 0, 'right-hand': 1} # pytorch expects labels in [0, n_classes-1]
    channel_names = ['F3', 'FC3', 'C3', 'CP3', 'P3', 'FCz', 'CPz', 'F4', 'FC4', 'C4', 'CP4', 'P4']
    info = mne.create_info(ch_names=channel_names, sfreq=fs, ch_types='eeg')
    epochs = mne.EpochsArray(eeg_data, info, verbose=verbose, tmin=t_start-3.0)
    epochs.set_montage('standard_1020')
    epochs.filter(1., None)
    epochs.apply_baseline(baseline=(-.250, 0)) # linear baseline correction

    if mode == 'train': # this in only applicable for training data
        epochs.event_id = event_id
        epochs.events[:,2] = mat_data['Labels'].ravel() - 1
    return epochs

def get_labels(filepath):
    mat_data = loadmat(filepath) # read .mat file
    return mat_data['Labels'].ravel() - 1

# %%
epochs, labels = get_mne_epochs(training_files[0], verbose=verbose), get_labels(training_files[0])
data = epochs.get_data()
print('Shape of EEG Data: ', data.shape, '\t Shape of Labels: ', labels.shape)
# Out:
# Shape of EEG Data:  (80, 12, 3072) 	 Shape of Labels:  (80,)

# %% [markdown]
# ## Data Processing

# %%
# loading original data
epochs_list = []
for i in training_files:
    epochs_list.append(get_mne_epochs(i, verbose=verbose))

# %%
len(epochs_list)
# Out:
# 10

# %%
# split epochs_list 60 trials train and 20 trials test
epochs_list_train = []
epochs_list_test = []
epochs_list_val = []
for epoch in epochs_list:
  # train_epoch = mne.concatenate_epochs([epoch[0:50], epoch[70:80]])
  train_epoch = epoch[0:40]
  test_epoch =  epoch[50:70]
  val_epoch = mne.concatenate_epochs([epoch[40:50], epoch[70:80]])
  epochs_list_train.append(train_epoch)
  epochs_list_test.append(test_epoch)
  epochs_list_val.append(val_epoch)

# %%
len(epochs_list_test)
# Out:
# 10

# %%
epochs_list_train[0]
# Out:
# <EpochsArray |  40 events (all good), -1 – 4.99805 s, baseline -0.25 – 0 s, ~11.3 MB, data loaded,
#  'left-hand': 20
#  'right-hand': 20>

# %%
epochs_list_test[0]
# Out:
# <EpochsArray |  20 events (all good), -1 – 4.99805 s, baseline -0.25 – 0 s, ~5.6 MB, data loaded,
#  'left-hand': 10
#  'right-hand': 10>

# %%
epochs_list_val[0]
# Out:
# <EpochsArray |  20 events (all good), -1 – 4.99805 s, baseline -0.25 – 0 s, ~5.6 MB, data loaded,
#  'left-hand': 10
#  'right-hand': 10>

# %% [markdown]
# ### [0.5, 4.5] sec and 2sec window with 125ms stride

# %%
from braindecode.datautil import create_from_mne_epochs

# convert epochs to braindecode compatible datastructure
# 2sec windows with 0.125 sec stride
window_size = 1024 #512 #50 # 3072
window_stride = 64 #256 # 50

# %%
windows_datasets_list_train = []
for epoch in epochs_list_train:
    windows_datasets_list_train.append(
            create_from_mne_epochs(
            [epoch.crop(tmin=0.5, tmax=4.5, include_tmax=False)], # [0.5, 4.5] s, expects list of epochs
            window_size_samples = window_size,
            window_stride_samples = window_stride,
            drop_last_window = False
        )
    )

# %%
windows_datasets_list_test = []
for epoch in epochs_list_test:
    windows_datasets_list_test.append(
            create_from_mne_epochs(
            [epoch.crop(tmin=0.5, tmax=4.5, include_tmax=False)], # [0.5, 4.5] s, expects list of epochs
            window_size_samples = window_size,
            window_stride_samples = window_stride,
            drop_last_window = False
        )
    )

# %%
windows_datasets_list_val = []
for epoch in epochs_list_val:
    windows_datasets_list_val.append(
            create_from_mne_epochs(
            [epoch.crop(tmin=0.5, tmax=4.5, include_tmax=False)], # [0.5, 4.5] s, expects list of epochs
            window_size_samples = window_size,
            window_stride_samples = window_stride,
            drop_last_window = False
        )
    )

# %%
# windows_datasets_list_train
# windows_datasets_list_test
# windows_datasets_list_val

# %%
len(windows_datasets_list_train)
# Out:
# 10

# %%
windows_datasets_list_train[0][0]
# Out:
# (array([[ 42.84346  ,  57.55566  ,  -6.910057 , ..., -47.189068 ,
#          -84.53391  , -26.119097 ],
#         [ 63.35543  ,  81.06551  ,  -1.9977584, ..., -45.45282  ,
#          -81.216805 , -10.636304 ],
#         [ 70.022354 ,  76.084    , -19.760208 , ..., -33.182205 ,
#          -76.468445 , -16.374454 ],
#         ...,
#         [ 45.264866 ,  64.99564  ,   2.563443 , ..., -33.443333 ,
#          -73.42125  , -15.326817 ],
#         [ 50.250744 ,  76.19861  ,   5.3295617, ..., -44.18488  ,
#          -88.172806 , -15.270915 ],
#         [ 59.11915  ,  68.972176 ,  -2.2951732, ..., -40.723244 ,
#          -77.005905 , -12.628537 ]], dtype=float32),
#  0,
#  [0, 0, 512])

# %%
def get_windows_datasets_labels(windows_dataset):
    labels = []
    for i in range(len(windows_dataset.datasets)):
        labels.extend(windows_dataset.datasets[i].y)
    return np.array(labels)

# %%
windows_datasets_labels_list_train = []
for windows_dataset in windows_datasets_list_train:
  windows_datasets_labels_list_train.append(get_windows_datasets_labels(windows_dataset))

# %%
windows_datasets_labels_list_test = []
for windows_dataset in windows_datasets_list_test:
  windows_datasets_labels_list_test.append(get_windows_datasets_labels(windows_dataset))

# %%
windows_datasets_labels_list_val = []
for windows_dataset in windows_datasets_list_val:
  windows_datasets_labels_list_val.append(get_windows_datasets_labels(windows_dataset))

# %%
# windows_datasets_list_train
# windows_datasets_list_test
# windows_datasets_list_val
# ####
# windows_datasets_labels_list_train
# windows_datasets_labels_list_test
# windows_datasets_labels_list_val

# %%
len(windows_datasets_labels_list_train)
# Out:
# 10

# %%
# windows_datasets_list_test

# %%
print("Total Windows in a Train Dataset: ", len(windows_datasets_labels_list_train[0]))
# Out:
# Total Windows in a Train Dataset:  1000

# %%
print("Total Windows in a Test Dataset: ", len(windows_datasets_labels_list_test[0]))
# Out:
# Total Windows in a Test Dataset:  500

# %%
print("Total Windows in a Val Dataset: ", len(windows_datasets_labels_list_val[0]))
# Out:
# Total Windows in a Val Dataset:  500

# %%
print("Total Windows in a Val Dataset: ", len(windows_datasets_list_val[0]))
# Out:
# Total Windows in a Val Dataset:  500

# %% [markdown]
# ## Processing

# %%
low_cut_hz = 8.  # low cut frequency for filtering
high_cut_hz = 32.  # high cut frequency for filtering
# Parameters for exponential moving standardization
factor_new = 1e-3
init_block_size = 1000

# %%
from braindecode.preprocessing import (
    exponential_moving_standardize,
    preprocess,
    Preprocessor,
)

# %%
preprocessors = [
    Preprocessor("pick_types", eeg=True, meg=False, stim=False),  # Keep EEG sensors
    Preprocessor(
        lambda data, factor: np.multiply(data, factor),  # Convert from V to uV
        factor=1e6,
    ),
    Preprocessor("filter", l_freq=low_cut_hz, h_freq=high_cut_hz),  # Bandpass filter
]

# %%
for windows_dataset_train in windows_datasets_list_train:
    preprocess(windows_dataset_train, preprocessors)

# %%
for windows_dataset_test in windows_datasets_list_test:
    preprocess(windows_dataset_test, preprocessors)

# %%
for windows_dataset_val in windows_datasets_list_val:
    preprocess(windows_dataset_val, preprocessors)

# %% [markdown]
# # Data splitting and conversion

# %%
windows_datasets_list_train[0][0]
# Out:
# (array([[ 1.38551623e-01, -1.40089203e+02, -1.28538315e+02, ...,
#          -4.14386368e+01,  1.08607063e+02,  1.25540741e+02],
#         [-4.40066650e+02, -5.70411926e+02, -1.55259762e+01, ...,
#           2.14133011e+02,  4.53180573e+02,  1.16058907e+02],
#         [-1.11367775e+02, -2.65115112e+02, -1.30591202e+02, ...,
#          -1.90326691e+01,  1.63858353e+02,  1.19796089e+02],
#         ...,
#         [-1.25597913e+03, -1.36236462e+03,  2.66068512e+02, ...,
#           8.63823792e+02,  1.27975635e+03,  1.31752991e+02],
#         [-1.10894299e+03, -1.20179968e+03,  2.19152435e+02, ...,
#           7.41544556e+02,  1.10100635e+03,  1.06557518e+02],
#         [-4.90930206e+02, -5.83403503e+02,  3.80975800e+01, ...,
#           2.63470795e+02,  4.98954041e+02,  1.09115707e+02]], dtype=float32),
#  0,
#  [0, 0, 512])

# %%
train_windows_list = []
for subject in windows_datasets_list_train:
  subject_windows = []
  for window in subject:
    subject_windows.append(window[0])
  train_windows_list.append(np.array(subject_windows))
  print(len(subject_windows))
print(len(train_windows_list))
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 10

# %%
test_windows_list = []
for subject in windows_datasets_list_test:
  subject_windows = []
  for window in subject:
    subject_windows.append(window[0])
  test_windows_list.append(np.array(subject_windows))
  print(len(subject_windows))
print(len(test_windows_list))
# Out:
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 20

# %%
val_windows_list = []
for subject in windows_datasets_list_val:
  subject_windows = []
  for window in subject:
    subject_windows.append(window[0])
  val_windows_list.append(np.array(subject_windows))
  print(len(subject_windows))
print(len(test_windows_list))
# Out:
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 20

# %%
# train_windows_list
# test_windows_list
# val_windows_list

# %%
# train_windows_list

# %%
type(train_windows_list)
# Out:
# list

# %%
type(train_windows_list[0])
# Out:
# numpy.ndarray

# %%
len(train_windows_list[0])
# Out:
# 1000

# %%
print(len(train_windows_list[0]))
print(type(train_windows_list[0]))
# Out:
# 1000
# <class 'numpy.ndarray'>

# %%
print(len(train_windows_list[0][0]))
print(type(train_windows_list[0][0]))
# Out:
# 12
# <class 'numpy.ndarray'>

# %%
train_windows_list[0][0].shape[0]
# Out:
# 12

# %%
train_windows_list[0][0].shape[1]
# Out:
# 512

# %%
print(len(train_windows_list))
print(len(test_windows_list))
# Out:
# 10
# 20

# %%
print(len(train_windows_list[0]))
print(len(test_windows_list[0]))
print(len(val_windows_list[0]))
# Out:
# 1000
# 500
# 500

# %% [markdown]
# ## Test Split

# %%
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from skorch.helper import predefined_split, SliceDataset

# %%
X_train_list = train_windows_list
y_train_list = windows_datasets_labels_list_train

X_test_list = test_windows_list
y_test_list = windows_datasets_labels_list_test

X_val_list = val_windows_list
y_val_list = windows_datasets_labels_list_val

# %%
print(type(X_train_list[0]))
print(type(y_train_list[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(type(X_val_list[0]))
print(type(y_test_list[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(type(X_val_list[0]))
print(type(y_val_list[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
X_train_list[0].shape
# Out:
# (1000, 12, 512)

# %%
X_test_list[0].shape
# Out:
# (500, 12, 512)

# %%
X_val_list[0].shape
# Out:
# (500, 12, 512)

# %%
len(y_train_list[0])
# Out:
# 1000

# %%
len(y_test_list[0])
# Out:
# 500

# %%
y_train_list[0].shape
# Out:
# (1000,)

# %%
# X_train_list = []
# X_test_list = []
# y_train_list = []
# y_test_list = []
# for subject_idx in range(len(X_list)):
#   X_train, X_test, y_train, y_test = train_test_split(X_list[subject_idx], y_list[subject_idx], test_size=0.2, random_state=42)
#   X_train_list.append(X_train)
#   X_test_list.append(X_test)
#   y_train_list.append(y_train)
#   y_test_list.append(y_test)

# %%
len(X_train_list)
# Out:
# 10

# %%
X_train_list[0].shape
# Out:
# (1000, 12, 512)

# %%
X_val_list[0].shape
# Out:
# (500, 12, 512)

# %%
y_val_list[0].shape
# Out:
# (500,)

# %%
# y_val_list[0]

# %% [markdown]
# # Model Training

# %%
# Creating a model
import torch
from braindecode.util import set_random_seeds
from braindecode.models import ShallowFBCSPNet, EEGNetv4
from braindecode.models import EEGInceptionMI
# Training time
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split
from braindecode import EEGClassifier

# %%
batch_size = 50
n_epochs = 15 #25 #20 #25 use few epochs for quick verification

# %%
cuda = torch.cuda.is_available()  # check if GPU is available, if True chooses to use it
device = 'cuda' if cuda else 'cpu'
if cuda:
    torch.backends.cudnn.benchmark = True
seed = 20200220  # random seed to make results reproducible
# Set random seed to be able to reproduce results
set_random_seeds(seed=seed, cuda=cuda)
cuda
# Out:
# True

# %%
n_classes=2
# Extract number of chans and time steps from dataset
n_chans = train_windows_list[0][0].shape[0]
input_window_samples = train_windows_list[0][0].shape[1]

# %%
print(n_chans)
print(input_window_samples)
# Out:
# 12
# 512

# %%
# model = EEGNetv4(
#     n_chans,
#     n_classes,
#     input_window_samples = window_size, #input_window_samples,
#     final_conv_length='auto',
# )

model = EEGInceptionMI(
    12,
    2,
    input_window_seconds = 2,
    sfreq  = 512
)

# Send model to GPU
if cuda:
    model.cuda()

# %%
from skorch.dataset import Dataset

# %%
val_dataset_list = []
for val_idx in range(len(X_val_list)):
  val_dataset_list.append(Dataset(X_val_list[val_idx], y_val_list[val_idx]))

# %%
# val_dataset_list[0]

# %%
len(val_dataset_list)
# Out:
# 10

# %%
lr = 1 * 0.02 #0.01
weight_decay = 0.5 * 0.001

clfs_list = []
for i in range(len(val_dataset_list)):
    clfs_list.append(
        EEGClassifier(
                    model,
                    criterion=torch.nn.NLLLoss,
                    optimizer=torch.optim.AdamW,
                    train_split=predefined_split(val_dataset_list[i]),  # using valid_set for validation
                    # train_split = ,  # using valid_set for validation
                    optimizer__lr=lr,
                    optimizer__weight_decay=weight_decay,
                    batch_size=batch_size,
                    callbacks=[
                        "accuracy", ("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),
                    ],
                    device=device,
                    classes=n_classes,
                    max_epochs=n_epochs,
                    )
                )

# %%
def training_function(subject_index):
    # dataset = windows_datasets_list[subject_index]
    clfs_list[subject_index].fit(X_train_list[subject_index], y=y_train_list[subject_index], epochs=n_epochs);
    best_validation_acc = clfs_list[subject_index].callbacks_[4][1].best_score_ # a hack to get best validation accuracy
    # best_validation_kappa = (2*best_validation_acc)-1
    print("Best Cross Validation Score: {:.2f}".format(best_validation_acc))
    test_acc = clfs_list[subject_index].score(X_test_list[subject_index], y=y_test_list[subject_index])
    print(f"Test acc: {(test_acc * 100):.2f}%")

# %%
# clfs_list[0].fit(X_train_list[0], y=y_train_list[0], epochs=n_epochs)

# %%
for subject_index in range(len(training_files)):
  print('\n', '#'*25, 'Training for Subject:', subject_index+1, '#'*25, '\n')
  training_function(subject_index)
# Out:
#  ######################### Training for Subject: 1 #########################
#
# Re-initializing module.
# Re-initializing criterion.
# Re-initializing optimizer.
#   epoch    train_accuracy    train_loss    valid_acc    valid_accuracy    valid_loss      lr      dur
# -------  ----------------  ------------  -----------  ----------------  ------------  ------  -------
#       1            0.9850        0.0470       0.5300            0.5300        6.4243  0.0200  35.3954
#       2            0.5270        0.0622       0.5280            0.5280        5.8823  0.0197  34.9178
#       3            0.7270        0.0308       0.5860            0.5860        3.1676  0.0190  35.0770
#       4            0.9800        0.0243       0.6220            0.6220        5.6471  0.0178  35.1225
#       5            0.9150        0.0127       0.6440            0.6440        1.7221  0.0162  35.0050
#       6            1.0000        0.0074       0.6780            0.6780        2.3180  0.0143  34.9535
#       7            1.0000        0.0016       0.6680            0.6680        2.9322  0.0122  34.9869
#       8            1.0000        0.0002       0.6580            0.6580        3.0169  0.0100  34.9585
#       9            1.0000        0.0005       0.6580            0.6580        2.9988  0.0078  34.9655
#      10            1.0000        0.0002       0.6480            0.6480        2.8370  0.0057  34.9344
#      11            1.0000        0.0006       0.6500            0.6500        2.9034  0.0038  34.9612
#      12            1.0000        0.0006       0.6500            0.6500        2.7576  0.0022  34.9882
#      13            1.0000        0.0001       0.6460            0.6460        2.8527  0.0010  34.9814
#      14            1.0000        0.0005       0.6400            0.6400        2.8737  0.0003  35.0142
#      15            1.0000        0.0002       0.6480            0.6480        2.9779  0.0000  34.9789
# Best Cross Validation Score: 1.00
# Test acc: 64.80%
#
#  ######################### Training for Subject: 2 #########################
#
# Re-initializing module.
# Re-initializing criterion.
# Re-initializing optimizer.
#   epoch    train_accuracy    train_loss    valid_acc    valid_accuracy    valid_loss      lr      dur
# -------  ----------------  ------------  -----------  ----------------  ------------  ------  -------
#       1            0.9800        0.6851       0.8180            0.8180        0.3746  0.0200  35.0224
#       2            0.7290        0.1037       0.6380            0.6380        1.3583  0.0197  35.0101
#       3            1.0000        0.0155       0.7800            0.7800        0.6982  0.0190  34.9661
#       4            1.0000        0.0069       0.8640            0.8640        0.3165  0.0178  34.9625
#       5            1.0000        0.0019       0.8740            0.8740        0.3295  0.0162  34.9450
#       6            1.0000        0.0028       0.8460            0.8460        0.4609  0.0143  34.9608
#       7            1.0000        0.0004       0.8720            0.8720        0.3859  0.0122  34.9600
#       8            1.0000        0.0006       0.8720            0.8720        0.3780  0.0100  34.9667
#       9            1.0000        0.0007       0.8600            0.8600        0.4082  0.0078  34.9636
#      10            1.0000        0.0003       0.8680            0.8680        0.3906  0.0057  34.9793
#      11            1.0000        0.0003       0.8640            0.8640        0.3891  0.0038  34.9797
#      12            1.0000        0.0004       0.8660            0.8660        0.3935  0.0022  34.9725
#      13            1.0000        0.0003       0.8620            0.8620        0.3856  0.0010  34.9608
#      14            1.0000        0.0005       0.8580            0.8580        0.4115  0.0003  34.9554
#      15            1.0000        0.0007       0.8620            0.8620        0.4021  0.0000  34.9615
# Best Cross Validation Score: 1.00
# Test acc: 86.20%
#
#  ######################### Training for Subject: 3 #########################
#
#   epoch    train_accuracy    train_loss    valid_acc    valid_accuracy    valid_loss      lr      dur
# -------  ----------------  ------------  -----------  ----------------  ------------  ------  -------
#       1            0
#      15            1.0000        0.0004       0.6933            0.6933        3.0523  0.0000  35.8391
# Best Cross Validation Score: 1.00
# Test acc: 77.00%
#
#  ######################### Training for Subject: 3 #########################

# %%
for subject_index in range(len(training_files)):
  print('\n', '#'*25, 'Training for Subject:', subject_index+1, '#'*25, '\n')
  training_function(subject_index)
# Out:
#  ######################### Training for Subject: 1 #########################
#
# Re-initializing module.
# Re-initializing criterion.
# Re-initializing optimizer.
#   epoch    train_accuracy    train_loss    valid_acc    valid_accuracy    valid_loss      lr      dur
# -------  ----------------  ------------  -----------  ----------------  ------------  ------  -------
#       1            0.4943        0.8294       0.4954            0.4954       59.5727  0.0200  71.8938
#       2            0.5000        0.5139       0.5092            0.5092        5.3554  0.0199  50.5486
#       3            0.6690        0.3248       0.6789            0.6789        1.0847  0.0197  50.4437
#       4            0.6356        0.2310       0.6284            0.6284        1.6120  0.0192  50.5390
#       5            0.7747        0.2025       0.7385            0.7385        0.5800  0.0187  50.5833
#       6            0.9333        0.1900       0.9633            0.9633        0.1494  0.0179  50.5905
#       7            0.6115        0.1549       0.5826            0.5826        1.7865  0.0171  50.5955
#       8            0.9517        0.0991       0.9495            0.9495        0.1498  0.0161  50.5755
#       9            0.9667        0.1499       0.9587            0.9587        0.2540  0.0150  50.5734
#      10            0.6287        0.0609       0.6193            0.6193        2.3538  0.0138  50.5792
#      11            0.6805        0.0273       0.6789            0.6789        1.5383  0.0126  50.5782
#      12            0.9874        0.0161       0.9771            0.9771        0.0610  0.0113  50.5705
#      13            0.7310        0.0180       0.7018            0.7018        0.9320  0.0100  50.5586
#      14            1.0000        0.0115       0.9908            0.9908        0.0177  0.0087  50.5629
#      15            0.9920        0.0084       0.9725            0.9725        0.0759  0.0074  50.5554
#      16            0.8506        0.0167       0.8394            0.8394        0.4806  0.0062  50.5303
#      17            0.9920        0.0082       0.9771            0.9771        0.0490  0.0050  50.5381
#      18            0.9069        0.0249       0.8761            0.8761        0.3166  0.0039  50.5306
#      19            0.9839        0.0059       0.9587            0.9587        0.0918  0.0029  50.5309
#      20            0.9897        0.0021       0.9633            0.9633        0.0807  0.0021  50.5286
#      21            0.9977        0.0036       0.9771            0.9771        0.0555  0.0013  50.5342
#      22            0.8598        0.0020       0.8119            0.8119        0.6054  0.0008  50.5317
#      23            0.9897        0.0012       0.9725            0.9725        0.0732  0.0003  50.5189
#      24            1.0000        0.0017       0.9954            0.9954        0.0083  0.0001  50.5291
#      25            1.0000        0.0034       0.9862            0.9862        0.0212  0.0000  50.5184
# Best Cross Validation Score: 1.00
# Test acc: 100.00%
#
#  ######################### Training for Subject: 2 #########################
#
#   epoch    train_accuracy    train_loss    valid_acc    valid_accuracy    valid_loss      lr      dur
# -------  ----------------  ------------  -----------  ----------------  ------------  ------  -------
#       1            0.5034        0.6419       0.5138            0.5138        0.8111  0.0200  50.5165
#       2            0.9023        0.3092       0.8807            0.8807        0.2820  0.0199  50.5302
#       3            0.7322        0.1586       0.7294            0.7294        0.8263  0.0197  50.6012
#       4            0.6621        0.1149       0.6376            0.6376        1.5397  0.0192  50.6579
#       5            0.9437        0.0434       0.9404            0.9404        0.1729  0.0187  50.6569
#       6            0.8839        0.0177       0.8945            0.8945        0.3214  0.0179  50.5333
#       7            1.0000        0.0130       1.0000            1.0000        0.0034  0.0171  50.4788
#       8            0.9989        0.0074       0.9954            0.9954        0.0127  0.0161  50.4654
#      21            1.0000        0.0004       1.0000            1.0000        0.0004  0.0013  50.5442
#      22            1.0000        0.0002       1.0000            1.0000        0.0004  0.0008  50.5004
#      23            1.0000        0.0001       1.0000            1.0000        0.0004  0.0003  50.4567
#      24            1.0000        0.0002       1.0000            1.0000        0.0004  0.0001  50.4556
#      25            1.0000        0.0001       1.0000            1.0000        0.0004  0.0000  50.4665
# Best Cross Validation Score: 1.00
# Test acc: 100.00%
#
#  ######################### Training for Subject: 4 #########################
#
# Best Cross Validation Score: -inf

# %%
for subject in range(len(training_files)):
    training_function(subject)
# Out:
#  ######################### Training for Subject: 1 #########################
#
#   epoch    train_accuracy    train_loss    valid_accuracy    valid_loss      lr     dur
# -------  ----------------  ------------  ----------------  ------------  ------  ------
#       1            0.5239        0.6587            0.5000        4.7591  0.0200  9.0020
#       2            0.6517        0.3797            0.5074        2.9087  0.0199  8.2990
#       3            0.7160        0.2881            0.5221        3.3227  0.0197  9.0790
#       4            0.7647        0.2320            0.5257        2.4932  0.0192  8.5510
#       5            0.9384        0.1507            0.7096        1.3055  0.0187  8.8320
#       6            0.5653        0.1403            0.5000        4.3148  0.0179  8.6180
#       7            0.9550        0.1484            0.7059        1.0289  0.0171  8.7350
#       8            0.9789        0.2000            0.6618        1.0018  0.0161  8.4860
#       9            0.9945        0.1222            0.5662        1.5762  0.0150  8.6930
#      10            0.9311        0.0543            0.5441        2.5212  0.0138  8.7700
#      11            0.9430        0.0687            0.6691        1.7588  0.0126  9.5760
#      12            0.9577        0.0430            0.7426        1.3381  0.0113  8.2957
#      13            0.9733        0.0360            0.6949        1.4980  0.0100  9.8776
#      14            0.9485        0.0302            0.6434        2.0020  0.0087  9.3530
#      15            1.0000        0.0410            0.6544        1.1031  0.0074  11.0020
#      16            0.9632        0.0358            0.5184        2.6758  0.0062  11.6134
#      17            1.0000        0.0184            0.6544        1.1441  0.0050  9.9170
#      18            0.9752        0.0261            0.6397        2.0280  0.0039  8.7560
#      19            1.0000        0.0270            0.6544        1.2429  0.0029  9.2900
#      20            1.0000        0.0205            0.6507        1.2457  0.0021  8.7120
#      21            1.0000        0.0176            0.6507        1.2017  0.0013  9.2610
#      22            1.0000        0.0158            0.6360        1.2492  0.0008  9.0830
#      23            1.0000        0.0165            0.6360        1.2863  0.0003  9.2380
#      24            1.0000        0.0166            0.6324        1.3253  0.0001  8.5440
#      25            1.0000        0.0227            0.6250        1.3527  0.0000  7.7970
# Best Cross Validation Kappa Score: 0.49
#
#  ######################### Training for Subject: 2 #########################
#
#   epoch    train_accuracy    train_loss    valid_accuracy    valid_loss      lr     dur
# -------  ----------------  ------------  ----------------  ------------  ------  ------
#       1            0.7601        0.4698            0.6985        0.8153  0.0200  8.3560
#       2            0.7040        0.2298            0.6213        1.1980  0.0199  9.1150
#       3            0.9283        0.1936            0.8346        1.0128  0.0197  8.5100
#       4            0.5699        0.1877            0.5000        4.3407  0.0192  8.8190
#       5            0.7776        0.1678            0.5404        1.5577  0.0187  9.2300
#       6            0.8438        0.1843            0.6728        0.8693  0.0179  9.3140
#       7            0.9752        0.1383            0.7941        0.4877  0.0171  8.7110
